# %% [markdown]
# # Intro to Deep Learning
# We're going to continue working with CAP imagery for the second half of this week. Recall the two main guiding questions for this week:
# - _What_ is in an image (e.g. debris, buildings, etc.)?
# - _Where_ are these things located _in 3D space_ ?
#
# ## Motivation
#
# We've already seen how structure from motion can begin to answer the second of those questions, at least in a coarse manner. The first question is more difficult than the second for one crucial reason: it (so far) can not be answered *solely* using image data. Recall that structure from motion was able to leverage image metadata, features and geometric constraints without having to insert any "outside" data. When detecting the components of an image, there is a certain amount of subjectivity that so far requires human input. For example, if you want to detect flooding in an image, there need to be some set of rules that the software can determine "if (rules are satisfied), then (flooding = True)".
#
# How can you start to tackle this problem? We're going to make the problem a bit simpler by turning it into a classification problem rather than a localization problem. That is, instead of finding where flooding is in an image, we'll find whether there is flooding at all. With that in mind, let's first try a naive approach and see if we can simply enumerate the rules. Let's look at some flooding images:
#
# <img src="notebook_images/010_1282_99809b0c-fc64-46e5-957f-7ff8e7547d8c.jpg" width="500"  />
#
# <img src="notebook_images/DSC_0655_0cbbe7e5-be24-4274-bf5a-664c6f2dc3e1.jpg" width="500"  />
#
# So what do we see? It looks like flooding is this murky, brown color that covers most of the image. So let's make a rule: if some percentage of the image is this brownish color (you can think of detecting this by creating some sort of index, like you did with the satellite imagery), there is flooding in the image. This might work for the two images we saw, but the real test is seeing if it works with other images. So let's look at another one:
#
# <img src="notebook_images/DSC_8218_7bb15c80-481b-411a-a54a-a36e9d8b6098.jpg" width="500"  />
#
# This image has a large percentage of it covered by brownish looking water. However, it's clearly not flooding, but rather just a lake. No problem, let's just make another rule: if some percentage of the image is this brownish color *and* there are also lots of buildings (let's also make an index for that), there is flooding in the image. Let's see if this works:
#
# <img src="notebook_images/DSC_8192_fe6812cd-c985-4e59-a62c-04a883ec42cc.jpg" width="500"  />
#
# Again, this is just some lake (the same lake as before, in fact). At this point, we might be thinking of shifting our strategy a bit. Clearly having someone sit down and enumerate all of the rules is impractical in this case\*. There is simply too much variability in the images to come up with a set of rules that is remotely generalizable.
#
# This is one of the major motivations of machine learning. The idea is that, rather than enumerate the rules that determine flooding, we're going to just enumerate the outcomes (e.g. whether there is flooding or not) and develop algorithms for the computer to *learn* what the rules are. There is a rich literature (and a host of undergraduate and graduate courses) on how these algorithms are designed, but on these next couple of days we will instead focus on how to interpret and implement them.
#
# \* This isn't to say that enumerating the rules isn't practical in *every* case. It really depends on the characteristics of the data.

# %% [markdown]
# ## A simple case study
#
# We're going to start with a simple dataset. We will use the  Breast Cancer Wisconsin (Diagnostic) Data Set (https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)), a dataset that shows whether a tumor is benign or malign and various other features.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import load_breast_cancer
# read the dataframe

df = load_breast_cancer(return_X_y=False, as_frame=True)["data"]
df["target"] = load_breast_cancer(return_X_y=False, as_frame=True)["target"] # benign is 1, malign is 0
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890       0
# 1                  0.1860          0.2750                  0.08902       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575          0.6638                  0.17300       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                  0.06637       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                  0.12400       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %%
# for now we're just going to focus on mean radius and mean texture.
# we'll plot one against the other, and color code depending on survival
df_b = df[df["target"] == 1]
df_m = df[df["target"] == 0]

# plotting
plt.plot(df_b["mean radius"], df_b["mean texture"], "ro")
plt.plot(df_m["mean radius"], df_m["mean texture"], "bo")
plt.xlabel("mean radius")
plt.ylabel("mean texture")
plt.show()

# %% [markdown]
# So what do we see? Clearly there are factors beyond the ones plotted that explain whether a tumor is benign. However, it's not difficult to see a pattern here. The further up and to the right you are, the less likely you are to survive. So as a first attempt, we will have the software learn a *linear classifier*. This classifier will be a line that will classify you as benign if you are below the line, and malign otherwise.

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions

# setting the features and the targets
X = df[["mean radius", "mean texture"]]
y = df["target"]

# splitting training and testing set 80/20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Initialize SVM classifier
classifier = svm.SVC(kernel='linear')

# Fit data
classifier = classifier.fit(X_train, y_train)

# Printing parameters
coef = classifier.coef_
print(coef)

# Plot decision boundary
plot_decision_regions(X_train.values, y_train.values.astype(np.integer), clf=classifier, legend=2)
plt.xlabel("mean radius")
plt.ylabel("mean texture")
plt.show()
# Out:
# [[-0.67959772 -0.12284004]]
# /home/ragarcia/anaconda3/envs/ladi/lib/python3.6/site-packages/mlxtend/plotting/decision_regions.py:249: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %% [markdown]
# There is a lot going on here, so let's try to break it down. Recall that we are trying to determine whether a patient survives using just the (normalized) age and detected nodes. These are called the explanatory variables or *features*, and we refer to it as $X$. The variable we are trying to predict is the prediction variable or *target*, and we refer to it as $y$.
#
# The underlying notion behind machine learning is that patterns that hold in a subset of data will hold in the population as a whole. So in a sense, we care about the performance of the classifier on data that the algorithm has *not* seen by learning patterns in that data that we have seen. To this end, one of the major paradigms in machine learning is to separate our data into a *training set* and a *testing set*. The training set is a subset of the given data that we will actually provide to the algorithm to learn, while the testing set will be used solely to report the performance on data that the algorithm has not seen. In our case, we set 80% of the data as training data and 20% as testing data.
#
# There are numerous algorithms that can train on data. One of the more popular ones (especially before neural networks were introduced) are called *support vector machines* (SVM). We will not discuss how it actually does the learning, but suffice to say it takes in the training data and finds the line that minimizes the classification error. This line is called the *decision boundary* and it is defined by the following equation:
#
# \begin{equation}
# C_1(mean\ radius) + C_2(mean\ texture) = 0
# \end{equation}
#
# Where $C_1$ and $C_2$ are the coefficients of the linear classifier. So really, the function of the SVM is to find these two coefficients. The algorithm then does classification as follows:
#
# \begin{equation}
# y_{pred} =
# \begin{cases}
#     1               & \text{if } C_1(mean\ radius) + C_2(mean\ texture)\geq 0\\
#     0,              & \text{otherwise}
# \end{cases}
# \end{equation}
#
# ### Exercise
# - Look at the first 5 samples in the testing data set. Calculate the predicted target of each of the 5 samples?
# - Look at the corresponding targets. Are the predictions accurate? What proportion of the predicted values are correctly predicted?
# - Which of the two coefficients is most important? Why?

# %% [markdown]
# How good is our classifier? We can look at the performance of our classifier on the testing set to find out. Of course, an important metric to look out for is the accuracy:
#
# \begin{equation}
# \text{Accuracy} = \frac{\#\ (y_{true} == y_{pred})}{\# \ \text{samples}}
# \end{equation}
#
# However, for most applications it is also worth understanding what your *false positive* and *false negative* rate is. A false positive is a sample that is classified as a 1 but is in reality a 0, and a false negative is the opposite\*. The false positive rate is defined as $\frac{\# \text{False positives}}{\# \ \text{False positives + True negatives}}$, while the false negative rate is defined as $\frac{\# \text{False negatives}}{\# \ \text{False negatives + True positives}}$. **Why would this be a metric we care about, especially in this case?**
#
# <details>
#     <summary>ANSWER</summary>
#     Imagine your tumor is predicted as malignant but is in fact benign. There is certainly now a cost you incur in further tests or surgeries, but ultimately it is a manageable cost. Now imagine if you predicted a tumor as benign even thoguh it is malignant. Here, the mistake of the classifier could certainly cost you your life.
# </details>
#
# It turns out there is a useful tool called a *confusion matrix* that handily lays it out for you.
#
# \* It's worth putting some effort into what we call positives and negatives. Here, we use the term positive to mean 1 (benign) and negative to mean 0 (malign). However, anyone that has had a test of any sort knows that positive usually means that you have the disease (in our case, malign tumor). A lot of data science is communicating results, so something worth thinking about.

# %%
from sklearn.metrics import plot_confusion_matrix

predictions = classifier.predict(X_test)
accuracy = np.sum(predictions == y_test)/np.size(predictions)
print(accuracy)

matrix = plot_confusion_matrix(classifier, X_test, y_test,
                                 cmap=plt.cm.Blues,
                                 normalize='true')
plt.title('Confusion matrix for our classifier')
plt.show(matrix)
plt.show()
# Out:
# 0.9035087719298246

# %% [markdown]
# As a final note, we used two variables (radius and texture) because it made it possible to visualize. However, there is nothing preventing us from using the rest of the data set columns as part of our features. While visualization in more than 2D is much more difficult, the underlying principles are exactly the same.
#
# ### Exercise
# Explore this link which contains a number of classification datasets: https://archive.ics.uci.edu/ml/datasets.php?format=&task=cla&att=&area=&numAtt=&numIns=&type=&sort=nameUp&view=table. Using an SVM, attempt to predict the class of each sample. Consider the following:
# - While multiclass classification is possible, limit yourself thus far to datasets that have one class. Make sure that y is set up with two distinct numbers for the classes (e.g. 0 and 1)
# - Make sure that your dataset does not have missing values. If it does, handle them appropriately (e.g. by substituting it with 0 or with the mean of the column).
#
# How does your classifier perform? Report the accuracy and confusion matrix. What could be done to improve the performance?

# %% [markdown]
# ## Deep learning
# So far, we've worked exclusively with linear decision boundaries. However, usually data is much more complicated (as you should have seen from the exercise). Therefore, we might want to look for something that has higher predictive power. One of the most popular tools in machine learning has been the *neural network*. A neural network is (loosely) inspired by the way neurons are connected and operate. Let's first look at the simplest possible neural network and work our way up:
#
# <img src="notebook_images/nn_nohidden_new.png" width="500"  />
#
# Neural networks are made up of *layers*. In the image above, the neural network has two layers. The first layer is called the *input layer*, and the last layer is called the *output layer*. Each layer is composed of *neurons*. In the input layer, each neuron is one of the features from the training data. For example, the first neuron might be the mean radius, and the second neuron might be the mean texture. We're going to refer to each neuron by $x_{l, n}$, where $l$ is the number of the layer and $n$ is the number of the neuron within the layer. Using this notation, mean radius = $x_{1, 1}$.
#
# Each neuron in the input layer is connected to *every* neuron in the following layer by a *weight*. We will denote each weight by $w_{l, i, o}$, where $l$ is the layer at the tail of the arrow, $i$ is the number of the neuron at the tail of the arrow and $o$ is the number of the neuron at the head of the arrow. In the figure above, the color of the arrow corresponds to the value of the weight (blue means negative, red means positive). Every neuron in subsequent layers is equal to the sum of the products of the neurons and the weight that connects them. In this case, the neuron in the output layer is defined as:
#
# \begin{equation}
# x_{2, 1} = x_{1, 1}w_{1, 1, 1} + x_{1, 2}w_{1, 2, 1}
# \end{equation}
#
# Once you have the value of the output layer, you can obtain the predicted classification by applying some function to $x_{2, 1}$. An example of such a function would be similar to what we did previously:
#
# \begin{equation}
# y_{pred} =
# \begin{cases}
#     1               & \text{if } x_{2, 1}\geq 0\\
#     0,              & \text{otherwise}
# \end{cases}
# \end{equation}
#
# So training a neural network is simply finding the weights $w$ that minimize the error. If you are keen-eyed though, you might have realized that the example above is identical to what we were doing before. Therefore, we still have not arrived at a more powerful classifier. Let's try a more complicated neural network.
#
# <img src="notebook_images/nn_hidden_new.png" width="500"  />
#
# This network is similar to the previous one, but now we have an additional layer in between the input and output layers. All layers that are between input and output are called *hidden layers*, though functionally they behave in exactly the same way. As a quick concept question, **what is the value of $x_{2, 3}$? What about $x_{3, 1}$?**
#
# <details>
#     <summary>ANSWER</summary>
#     $x_{2, 3} = x_{1, 1}w_{1, 1, 3} + x_{1, 2}w_{1, 2, 3}$ ,
#     $x_{3, 1} = x_{2, 1}w_{2, 1, 1} + x_{2, 2}w_{2, 2, 1} + x_{2, 3}w_{2, 3, 1} + x_{2, 4}w_{2, 4, 1} + x_{2, 5}w_{2, 5, 1}$
# </details>
#
# Why are we introducing a hidden layer? Notice that each of the neurons in the hidden layer are essentially acting as linear classifiers. By having a weighted sum of these neurons in the output layer, we are arriving at a function that, by virtue of being a sum of lines is not itself linear. One of the biggest results in machine learning is that, as you increase the number of neurons in the hidden layer, you can approximate *any* function, meaning that you can always make a more powerful classifier by just adding more neurons. However, usually this is not computationally efficient. Rather, most of the time it makes more sense to introduce more hidden layers as opposed to more neurons, as shown in the image below:
#
# <img src="notebook_images/nn_deep.png" width="500"  />
#
# The added "depth" as a result of more layers is where the "deep" in "deep learning" comes. As computational resources have increased, scientists have increasingly resorted to adding more and more layers to their neural networks.
#
# ### Exercise
# Let's start thinking about the LADI dataset. We want to use deep learning to detect whether there is flooding in the image.
# - Using the paradigm above, what would be the features of the dataset? What are the targets?
# - Propose a way that you would input the features into a neural network?
# - What problems might you run into if you directly put an image into the neural network above?

# %% [markdown]
# ## Convolution
# Convolution is a fairly old technique in image processing. A short explanation on how convolution works is given here: https://towardsdatascience.com/computers-that-learn-to-see-a2b783576137
#
# As you can see, different kernels can pick up different features depending on the specific coefficients of the kernel. In the late 1980s, scientists first thought to use neural networks to learn the kernel values themselves, which created the foundation for the *convolutional* neural network (CNN). These complement the hidden layers from the previous architecture with new convolutional layers, which perform convolution on the previous layer. In so doing, these networks conserve the relationship between nearby pixels and perform very well in image classification.
#
# <img src="notebook_images/cnn.png" width="500"  />

# %% [markdown]
# ## The LADI dataset
# As we already saw, the LADI dataset contains CAP images as well as crowdsourced labels for a number of different categories. Today we're going to start the multi-day exercise of applying deep learning to the LADI dataset in order to do classification of flooding. This section borrows heavily from the following tutorial: https://github.com/LADI-Dataset/ladi-tutorial
#
# ### Data reading and cleaning
# We first have to go through some work to make sure that we only have the components of the dataset that we want.

# %%
# read the tsv file with the labels
file = pd.read_csv("http://ladi.s3-us-west-2.amazonaws.com/Labels/ladi_aggregated_responses_url.tsv",delimiter='\t',header='infer')
file
# Out:
#                                                       url  WorkerId  \
# 0       https://ladi.s3-us-west-2.amazonaws.com/Images...         0
# 1       https://ladi.s3-us-west-2.amazonaws.com/Images...         1
# 2       https://ladi.s3-us-west-2.amazonaws.com/Images...         2
# 3       https://ladi.s3-us-west-2.amazonaws.com/Images...        20
# 4       https://ladi.s3-us-west-2.amazonaws.com/Images...         0
# ...                                                   ...       ...
# 289835  https://ladi.s3-us-west-2.amazonaws.com/Images...       488
# 289836  https://ladi.s3-us-west-2.amazonaws.com/Images...       496
# 289837  https://ladi.s3-us-west-2.amazonaws.com/Images...       516
# 289838  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
# 289839  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
#
#                         Answer
# 0       ['damage:flood/water']
# 1       ['damage:flood/water']
# 2       ['damage:flood/water']
# 3       ['damage:flood/water']
# 4       ['damage:flood/water']
# ...                        ...
# 289835         ['damage:none']
# 289836         ['damage:none']
# 289837         ['damage:misc']
# 289838         ['damage:none']
# 289839         ['damage:none']
#
# [289840 rows x 3 columns]

# %%
# Strip off bracket and comma from the Answer catagory
file["Answer"] = file["Answer"].str.strip('[|]')
file["Answer"] = file["Answer"].str.split(",",expand = True)

# Extract labels with damage and infrastructure categories
label_damage_infra = file[file['Answer'].str.contains('damage|infrastructure',na=False,case=False)]

#Filter out infrastructure label with label 'none'
label_clean = label_damage_infra[~label_damage_infra['Answer'].str.contains('none',na=False,case=False)]

# Extract data with label does contain 'flood'
label_flood = label_clean[label_clean['Answer'].str.contains('flood',na=False,case=False)]

# Extract url data with the label does contain 'flood'
im_flood_lst = label_flood['url'].unique().tolist()

# Extract url data with the label does not contain 'flood'
label_notflood = label_damage_infra[~label_damage_infra['url'].isin(im_flood_lst)]
im_not_flood_lst = label_notflood['url'].unique().tolist()
# Out:
# ['https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0054_dd2c9af2-2f82-4275-91e8-59bf558b5e58.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9124/615914/DSC_0042_92be222a-4f69-45e7-ad07-4866aef81758.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9086/614468/VIRB0416_655a5a29-1899-4757-b9e7-523913d52fe7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9113/615620/VIRB0108_41dc3038-7322-404a-98db-98e386776b87.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/100502/010_1282_99809b0c-fc64-46e5-957f-7ff8e7547d8c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291486/VIRB0598_3abd9ed5-4009-4b74-b0f6-524875827213.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9077/614197/VIRB0501_675de0e9-7a94-4659-a610-e20636951e90.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0655_0cbbe7e5-be24-4274-bf5a-664c6f2dc3e1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2020/70349/DSC_0463_196a704f-336d-4606-bb6f-4611af06bb66.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1894_cb702bda-7c31-4e56-b104-d69ca0adef42.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613600/DSC_1307_b224ad1e-705c-46c9-b8c7-0cfcc6dc503e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2032/200890/_ARD4072_822523fe-f4d6-4695-8c17-6f14d855b446.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613783/ABW_0447_664b4765-8c43-4c26-bb66-ee404bed3418.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291586/DSC_0021_9f8c6845-1348-4579-a0ab-779d5adbf263.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613901/DSC_7815_cd41e402-d441-4604-8511-0966456cf39e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2016/70332/DSC_0612_77003a7e-4d2b-4a1c-a4b7-7031106c3c46.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5060/443388/DSC_0017_aa5470e4-c7dc-421a-ad1a-2172027f2334.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_4700_5587bc9e-bba3-4a4b-85a9-2fbc95a6fa4d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291550/DSC_0856_bd768f51-316d-47b7-a5a8-90e014d2d53b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613824/DSC_1489_3efa50e5-36ed-4968-b79d-29a7b8e9f576.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7066/543520/DSC_0066_564e9134-da99-41ca-b6b5-405f15bdd920.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613809/DSC_8180_5184f2ef-0449-44e5-b6d6-71efebe4bcfd.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0445_cbfe8818-b08c-45e5-939c-603de85e6088.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9124/615920/_DSC0034_a741f403-db0d-4e88-89d5-4c4144ddc064.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291534/_DSC0569_4a3fe4ac-95fc-498f-945e-817e87b52581.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291636/DSC_0408_6d12ce63-35a4-4712-88a5-e93aeb7b7726.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2016/70341/DSC_0893_e824cab5-e511-428e-812f-a2912133ee92.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613934/010_8818_575844c7-b406-47a4-8224-9513496108f1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9082/614361/IMG_6335_cbb7b44e-73e6-42d6-b7a2-691f36fd3b66.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291528/DSC_1601_75d6e6e9-62bb-4ba2-9f08-e7f3323b0c9c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9117/615776/DSC_5802_db8ac1da-7042-4adc-8704-c4cc12c9802d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2027/160703/2016-02-_64bb3da2-0c41-4331-88d1-47d78ef98472.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291504/CAP_0066_83862224-da4f-4c78-a3d1-8093fba6437e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613892/020_9905_e8d1ec8e-79c4-4042-8f0b-1c9797348773.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613904/CAP_1684_cfb10e22-a46e-4c98-a074-72c0ac4a8cb9.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291548/DSC_2641_77165785-a091-455e-bb55-0ca74451198b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2016/70327/DSC_0241_9a8fb92b-ba86-4589-a88e-ef9ddef7a0a2.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9132/615978/DSC_1991_2cc8884a-db0f-4d83-b528-8a2fdba407e8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613934/010_8681_41e5507b-c465-4a87-ba95-5d48e13a2390.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291617/DSC_0247_b866fc84-2f60-49fc-9949-20db70e7eb05.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613805/65bd4c97-d6c1-4d47-8685-10a63731a509.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291529/CAP_0311_dc54c010-42fc-4993-a1a7-449e1fe552d4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615130/DonBarre_39af46bb-5160-403a-a3ec-e7390bd5d061.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291582/DSC_3181_adebd920-7641-446b-9d06-5d32fec2811a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613556/DSC_0577_a4713277-5afd-41ef-8d54-ab8fd6cc5979.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291618/DSC_7220_33489bbd-9313-46ca-8216-c8258b94eb86.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613885/DSC_7575_17503799-d667-429b-8e5b-12e6734b190f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0040_821daec8-4615-44e4-883f-a259e68092b6.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_0490_2294ccf6-7420-439c-80cf-81c239e56188.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614098/A0015_AP_0b2c1cef-ce89-4df3-8704-3744a13532c4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9132/615978/DSC_1962_b1f07b53-1189-4cac-923a-861b19bf25aa.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291559/CAP_3675_04a0b8a6-dd74-4eed-ba94-5b736cc97f78.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9129/615884/DSC_1188_d77cae73-a0d0-4a9c-84e9-e1b104dded2e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9084/614779/VIRB0331_4c8cd8e4-f887-4ed2-ab26-5c16c11e8168.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613828/020_3362_5c0173b7-8b2a-46ec-ad9e-acace68dab76.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9129/615852/A0007_Je_39bffbe5-dfa9-47dc-9683-d7d894f3550b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291630/DSC_0201_5fbab06e-9252-423f-b1f5-c46283c62f74.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9084/614741/VIRB0183_270ee6a2-8882-4f57-8611-049f217eba3e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291633/DSC_3565_74e784d4-4914-4121-96d2-814881b2cc8a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613743/DSC_0237_610cc0ec-cba5-4a92-8b71-1faf61855e08.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613946/DSC_4773_59afc11d-b6d5-44ab-8588-0e2589ba0431.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7063/443410/DSC_3693_6cffaaf5-8e69-4304-982d-94f7ec890d17.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613904/CAP_3122_c85ace14-a8c6-43e7-b8e5-db2bcfebe0db.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613829/DSC_8910_5b8f0ed3-e8e9-4323-b806-a3e8579b6098.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615123/ChrisPet_315ba0ee-1168-494f-95f1-f65a470bc89a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_1311_716441aa-5754-4841-ba97-0f107dd94a6c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613542/DSC_0415_aee8b7ae-6dfc-4d0e-a8ca-fecf6abfd1ee.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291524/DSC_0315_62936e86-f20c-4753-9c6e-3036f56b4715.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9089/614553/DSC_1551_73efd393-08da-4d68-bc1d-1695ad80aa29.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/6064/423324/041_117a21f3-a107-4ab4-ae47-a51c155397a1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/6064/423318/DSC_0835_80b2dd54-7af4-420e-a218-3fd4883e3323.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613934/010_9301_a924b6d6-a0ab-42cc-b532-30dd73227c5e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613544/DSC_0248_67dbe255-4a41-47b6-b407-03031789b96f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613904/CAP_1616_7fe7c880-c477-48df-8db1-c587e732531b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7063/443432/DSC_2543_281fd2bb-f118-4e63-8a07-c93f5f78a1ed.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613928/DSC_2390_ba2fd972-c27c-460e-9189-a7293542e224.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613940/DSC_2233_8dc5fc6f-1625-44f4-bbee-2672323207c6.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613828/020_4675_2dc6ef18-30f3-416f-80d6-6020aacc7df0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291521/CAP_3233_bc8c5e7d-e2f0-4bb2-b5f7-051807247ced.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5055/382400/DSC_5444_b3d70ceb-30ab-4c7d-ad0a-6a4046388259.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2331_b28f6da6-9176-40e1-b2f1-89d87cf30fec.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613890/DSC_4358_a1d445b9-9a25-4ee8-af07-c975b77cb456.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613891/DSC_4903_17f815a3-407a-4b0c-9216-7aede1ad2601.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613862/DSC_0976_2e833bcd-1e50-4a82-a154-9395735fb741.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615186/-085_c1b32c57-a925-4f8c-a6c4-7fcb53208f01.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613877/DSC_0300_94303b07-837e-4da6-87ce-9f50edaad40b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0843_a296a961-d9ff-4bb0-882c-ea2c5a12787e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613904/CAP_2576_d064b0cf-129d-4385-8e9f-761b4dd6c2c7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613934/010_9546_5b29f331-44be-432c-9b40-5cfcf6dfba24.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291651/DSC_0214_9ac84659-5f11-4dd0-a817-9c51a710efde.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291564/_DSC0694_b97352f6-ef4b-4500-9a10-56a049a1c76a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613935/DSC_2161_e99da49f-311b-4c50-a62b-eb0ac57d1a03.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615050/DSC_3612_9287b5a2-f7df-47b7-ac4e-a90ab684719a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2033/211152/A0078167_df8b766a-ed9b-4506-ab74-1f9b2ff80471.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9082/614359/DSC_1411_ac07b3ed-32c0-4521-9179-b8e440f25ce5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9132/615931/DSC_0487_00056319-98f3-4fda-9497-2ad4a444dd88.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613903/DSC_0855_02d388eb-bcc7-4d01-91a2-f4130e422ae2.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9121/615662/DSC_0073_793438f4-f6f1-42f3-bbff-2ef0491f7303.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613827/DSC_9022_3ddc2ecb-d7cb-49ff-a4e2-be3819b55f92.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613934/010_9834_e7cc10b5-f9ae-423b-8e35-986235761e50.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613769/DSC_6326_c855f478-3ccf-4db3-8493-9a6db36680a0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613805/c963ecbd-0a1a-4b01-8f6c-2ecf23018c45.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615163/DSC_7393_d780c239-b79c-4ab1-a323-bc387ce07870.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291506/DSC_0960_a7e6aa52-6be7-42f8-8ebd-e408fb23362b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613940/DSC_1780_5a8f8eb8-cb89-47ef-8bf2-855e31c28346.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613828/020_4632_461660c0-5d0c-4a4b-8f78-6323b88afcf8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613645/DSC_0223_1ff47b3e-afe7-4a20-8624-9c71fa8f6ca6.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613734/ALW_3843_5a5e970d-3974-4bfa-8825-df1748d2ade8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614133/A0029_AP_f2b57e01-ce40-471d-9f47-990830f9c128.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1088_f15d2098-fd80-40f7-bcaf-4d63745e63e7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291669/DSC_0217_5fb03ca4-d5f8-479a-914a-04f9403cadf8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9079/614812/DLC_0129_3508932f-a789-4402-9af9-13ad0b4ac462.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291542/DSC_0738_b60ccc7f-dbd8-4ac2-9039-298a4f805ce1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291542/DSC_0170_ec3b9a68-018b-455e-8526-f4c43318e182.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9132/615952/DSC_1754_38f8069d-2a90-4601-87fa-6b7623d3a75c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615156/DSC_1078_75ef8e14-0a72-4971-a9f8-db21ead06581.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613901/DSC_7309_dcb33c80-8023-41c7-a168-bf80aa70be82.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291559/CAP_3557_46212664-f643-407b-8fa3-1e4609797f69.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20199/DSC_0041_c7a676dc-4ded-4780-a17b-5eb1b748a2e7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613936/DSC_5428_4f5cbbf9-94e3-4370-823f-e800da3393ba.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291548/DSC_2091_45a8c20f-d65f-4562-986d-8425d3d809ef.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613934/010_9486_043f291c-2f0e-416d-87df-4a68b62b3db8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613880/DSC_1505_5636566c-ada6-4c14-8f35-b9b374740481.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9113/615654/DSC_0243_2091fc74-41f9-4be0-87db-51ea0e27e485.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613942/DSC_1735_c76cfc35-d749-4c71-a154-d06cc7a97c02.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291609/DSC_0115_5b79f878-7139-44e4-9107-9771c7f7d8f0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5060/443388/DSC_0092_a714823d-9c56-463f-902c-d5c4180ba4b7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615028/DSC_7189_068d00a6-a8dc-483f-b72c-4c5de9a5c65d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291547/DSC_2464_84b59cf4-53de-4e60-a2d0-a3b37e1da568.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0826_45d52626-0634-403d-8098-01e8dc6acf4a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615107/DSC_0182_ee4cfc5e-ae3a-492c-b9e6-94f8d5af5cba.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613927/DSC_0346_a6f0a4aa-88c8-46eb-86b9-936e0b3a81c3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0088_a6e4c0ef-dcfb-42a8-9a86-6fc3754cd14a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613947/DSC_2794_657332db-19b0-4361-af28-038e7535dcee.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613818/DSC_7265_7897eeea-4af4-4f8c-8520-55d5332dfbaf.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9084/614893/VIRB0155_300889c3-66f2-436e-9446-a84f7e43915c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0344_0898cc25-1c60-46cd-bcbb-2e26e909d093.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9129/615884/DSC_1434_0679a982-4656-47b1-88de-59a4024f077d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9148/615925/DSC_3175_b35a00f3-e87b-4841-9534-b9212a02b6b4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_0785_1e726c50-da6a-47d1-a195-d4f174e3c84c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0925_875decf4-50b9-4259-91e8-fcb88a0ed07a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9113/615654/DSC_0060_51b69294-7e85-421b-bece-e80c9490a246.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9082/614358/DSC_6432_54f8d471-7302-4b6d-a168-69811e334548.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/613976/A0014-73_5106ec85-c13e-4ef7-bdc1-96a99cdd7ca6.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9084/614740/VIRB0239_c9d0c3da-b8af-4c80-98c5-70961ac46e7b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613586/DSC_1147_bf3d03db-8662-4faa-baa3-738f4071dab3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_0083_9bbd76af-2cd9-4a0f-9446-7daad4609287.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613727/DSC_0454_a31f1b56-a8f9-4297-9e7c-64e37f12438a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613822/_CAP0953_c4dd6713-9056-4f66-af4d-d6cbdcdf7356.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5060/443388/DSC_0577_73583832-0721-4415-9476-ec0d2ef84d0e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20165/CAP_1741_56265682-5ced-4326-972e-890025de2b27.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5060/433345/DSC_3539_e2898fde-95ea-404e-97d0-68cd57329173.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8176_3f26ab82-3b01-4370-940f-437a20497070.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8158_f7177ece-485c-4ee2-9e61-bb8743314e3a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7946_55318e5a-6602-4540-9a97-f85c1be03815.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7823_2aff03be-b8d5-45b6-80f7-07289ea2957c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7794_7a2b39ae-2bed-49c1-bc8c-825c962c2c29.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615133/DavidBen_dcc8c8e5-010d-414e-9bca-e0f506d79ae3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615133/DavidBen_1999d673-43e4-4dba-b86b-13d955ef4dd9.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615133/DavidBen_412e8744-4530-49c6-bd0b-9c172d610e67.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615133/DavidBen_c4852450-9bda-42ab-9552-b46018064a6b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615133/DavidBen_341619c9-98d2-4777-ae29-011290bd476f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_9e816249-2f83-4961-b736-21289f19bf4b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_9043b294-fb73-4667-9c12-9f2f6d1449ff.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_2fa500f0-a910-4eb5-acd8-07a67b2739e8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_98cc1afe-150f-4899-8c13-1c465560bd23.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_cf92eff9-b196-4d6b-8047-5a405763a29f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_f2d7e634-d3dd-4a37-a3ce-0ba988bd18e1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_3ddf0d6d-2a52-467d-9573-ad9c22086a7e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_212f5aa1-befe-457f-9f11-f82045299a9e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_9c2e0623-e326-475e-a0ac-924cad114414.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_a12be485-31f9-4120-b6b3-cbdad3c81e6d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_ddc0d324-6bb4-45fd-ad2e-2ad06ed43ec0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_8229cb5d-4986-47ad-99e8-3dc34eeab99f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_a65ae09c-0d32-4b7e-beab-53cd9a927734.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_b64aee86-43bd-4c87-a0ed-2477a4b4ed4d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/joebell-_db3fb4a2-fe85-4161-8b3d-7371f11be470.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615130/DonBarre_a64ee05d-7737-4c3c-bb41-01e906219e90.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615130/DonBarre_79cb8e69-c7cd-40dc-a5a3-ce7c2f4ed386.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615130/DonBarre_635a4af6-f417-44bc-ac18-772d29c79ed8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_cd62548a-1d40-4fe6-8a55-8db0b41535b5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_618d9463-b862-4591-bfca-678c1862dad7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_27d334e4-89f4-4d45-99f6-5b721c7e59ac.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_a09952c5-9908-4184-8544-54738baab0d7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_6421fab8-cfec-478f-950e-ecadecacf15a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_f737d044-339d-47f6-ad31-1e67d34ff07c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_2ea7bf52-cf1f-4c1d-988d-0ba61a011dc6.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_8f3b2ebe-430a-4c83-b431-796d87277874.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_de33a4f2-9411-430d-b8a1-9b1efb0f5487.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615129/BrettGro_4fc5a172-2344-42de-97ae-ff2241789218.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_3bb55367-30d8-4ebf-a9a6-c298ad59feeb.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_0c7ced41-e37e-4ada-9a32-7fe94cec2fdd.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_a10a2f5d-1748-497b-a7f3-6fb083f8a2db.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_032e63f7-8cd9-48c8-989f-4c52d1e21bd1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_29ee9c9d-7b84-4e7a-a80f-666b09761698.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_96fcaccb-145a-474d-9a75-aa19a679c1a5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_2f8655f7-e949-43a1-9c9e-c01e5e2381e3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_0fe86cb2-e5f0-4f6b-9443-ed64828061ed.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_4cfb5fae-8ea7-45af-a5a2-52b6efdf2f5d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_6449e9be-2c1f-4fac-ab05-b7917948c482.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_5f77f6f3-2f8b-4111-aff6-edaf5b9be8b2.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_8368ae9a-8cc0-44fd-9797-826e4404f6c1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_4d7aaddc-659c-482b-bd5a-06af4627f7d7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_f2a61c51-c9cf-4edd-952e-3a943f4e278d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_d0a44745-36bb-4d9a-85b0-d64eca67307a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_5057c966-7aef-4619-9a63-359201502847.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_682bcd44-c4d8-4ce7-b4ca-06485a3b1f94.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_d0720c29-af78-411d-af80-46df1c9760e0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615125/MarkBail_82225a37-d335-4c99-9782-e67d5f12e571.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_b72f147c-b0e4-4a1d-881f-c2886b9ae45c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_0225399b-05bb-491c-b415-741c1b5cc04a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_f5fd304d-abc6-4eca-b04c-1759bd9fde98.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_86cc734b-14a4-495e-9f0e-41e96add2960.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_450219a2-096c-4e2f-b63a-c295ffe24e6b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_8271d6e3-7ce9-48e7-ad9d-e9fb40309fb8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_363af209-e436-4102-8c16-0a6a8060cb03.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_45dcd073-6874-4302-8a60-f211e4a1e66b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_0d7231cd-1c99-4e8a-bf73-8eb749643e1b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615126/SteveBla_7a747c28-b43b-4886-948d-b359c660b95d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613829/DSC_0898_c0f92034-f16e-4c0e-bd21-18fec14ea443.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615077/DSC_3963_2428c4a1-dd6a-4e1f-9de7-a156a1775c67.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9088/614510/CAP_5088_f18a0f60-819c-4f7c-87f4-2decf29b984c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613927/DSC_1140_0a73583e-69e4-4704-8ee5-2e4689b1a3ca.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613883/DSC_1455_d1cb21e8-3278-4adf-906c-442fd667ce9e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_0230_e0ce1850-ec77-4c1c-a72c-48ef23b2af61.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614089/A0074_AP_76f44482-a446-4a79-aac2-ac37fc606df1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291580/DSC_0332_684a9103-7be1-4237-8185-da441a1555b0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613894/DSC_5829_56ed54c9-9bca-4b04-8d5f-ba0b8f68ab22.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1041_ddac8feb-f6b3-4021-a847-ed861e8e8cb0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20187/DSC_0302_427b2dc3-0bd6-4f70-8aac-d95b2fb121da.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0298_a042826d-8d23-4b8f-aebf-c8bf99892a12.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613828/020_2878_6d533bbf-1857-48f6-9218-93e903bdbcb0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0051_5ebd5e3d-a509-4f95-b092-1be0986a59de.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613542/DSC_0037_598127f9-de24-41f4-91b7-a3fd5f801d0d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7068/615404/DSC_7889_47681bd5-467c-46f8-a5cd-15c43c92ded1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613897/DSC_5168_c4bc71d9-e5e6-4db1-b1f2-4a3db362fe06.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_3840_cd7a5cb0-7fdc-4fbd-ad2a-102c9fc7fa97.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613942/DSC_1872_26db4b05-1c23-47c2-9300-3159d532b3c2.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613899/DSC_4201_1cb10ae1-b6c9-4a8b-b0c5-583117721a70.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291610/DSC_0147_5f6ea69d-fd70-42ff-8ed9-0c451fe55003.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613793/DSC_0654_eb053e6c-cdfc-4493-9c7c-d30bcefc83e9.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_0290_90f406e9-6642-443c-9033-1e857ddbeece.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614001/A0027-96_14bae07e-5f47-4126-bf84-55010186b655.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_1866_7243e1c2-8831-420d-bef8-59e1a07b5d12.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613904/CAP_2013_5f969f29-9372-42c4-883f-6de7e13dbbc8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_0084_6282eb07-3c49-46dc-a0dc-934d7e1e3194.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613852/DSC_0061_32684700-9de6-4b8f-b4a8-f922a4d33e53.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613941/DSC_4276_654e9d5f-ad1a-4ca4-83cc-dc9f676264c5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9150/616087/DSC_4053_963fae9b-f969-4228-9d92-d842660e32b6.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291518/DSC_0303_9298cf0b-2535-4dcf-99c6-9bc570a6edfa.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291543/DSC_2857_a75ccf73-f174-4c07-a629-e05645a00e87.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613900/DSC_4998_780581e9-a508-4ed7-91d1-5205e85906af.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0553_1314e3bf-f2b5-41f5-b232-1caba436b248.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614029/A0070_AP_f4c245df-ba1c-4e28-a3c9-3172bd107ad0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0672_13ce6ea8-6217-447b-8c6f-9b335626f0ff.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613927/DSC_1097_be08c060-62f6-47b2-9125-cced2f727c6c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613903/DSC_0695_f76ec0cb-0b3a-4bba-b49b-6680e29695a5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/231185/DSC_0024_cdd216ed-0559-45bf-a81a-ff75f216d2b7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615083/DSC_0945_2f59be35-bed8-4475-8bda-4f5712107f6f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613946/DSC_4552_c8ae248e-3208-4af9-b8eb-421a9b364523.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291569/DSC_0070_9152ad11-a82f-46a1-8033-75ccbe6daf90.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9113/615619/_DSC6739_b6970840-7983-4fce-b4c3-30deea689a30.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291517/DSC_0298_d173e7c7-1e59-4e2f-906c-88b3902846d9.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_0581_7a645a9b-b85e-42cd-8c2b-4d1fc9d31bac.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2405_5e5ceddd-559e-4438-bcf1-976acc79b5d1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613735/DSC_0064_bece261b-e7cd-4a38-a859-c205bd908295.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613739/DSC_1378_91b6a09b-d4e2-4c31-aa59-cc74234baca9.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291518/DSC_0536_7be196b3-eb0e-41d6-98a1-432d552c64f4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613899/DSC_5547_6c888c29-d6a9-46f1-882c-73916a97854d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613947/DSC_5003_8e5f94e9-dded-4345-8521-a37f8af5973d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0698_b6ff9359-29fd-4c3f-86c7-b9cbc0d71a46.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291669/DSC_0170_6ef6c77d-c7d8-41c8-a69d-ada23f52c177.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613823/DSC_1527_eb73eaaa-b483-4298-823b-a92f1721f528.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613807/DSC_0521_d1c2afb6-b8ca-45bb-a0d1-45253d202552.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/583534/DSC_5711_6dd7c991-87b4-4275-ba36-e9566a0c0fa8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613542/DSC_0378_aaf5284f-a46b-4429-a5b0-63f513d8c9c8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613927/DSC_0945_5faad898-fe67-4936-aa98-7abc4a648855.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613940/DSC_1806_b90257a1-a517-4c4a-98be-5f9ae4044414.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613829/DSC_8914_7ccd056c-16c8-40ad-9d4e-74207d4631d0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_2546_24de30d2-2b1d-4266-b692-7437d7159e6b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613829/DSC_0044_93a9d9fb-be9d-4bcf-97a3-cd3b7e7c85ad.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615038/DSC_0084_6ee6234f-9ee1-41db-810c-c2a3ed0d747b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613799/DSC_2459_33228638-8b9e-435a-a0f0-48bcc95928bc.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291506/DSC_0393_1d94fe8e-1ad4-4a12-943b-05084bdd03b3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0361_86cef080-32a4-476e-8f34-c04f06a54126.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291663/DSC_0301_0a588239-93c5-4a11-9061-d58c8b7d64d6.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613906/DSC_5772_c5f03c52-0a57-4620-bfda-f0d219655c48.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20212/DSC_0450_30f1e666-9322-40fd-a74f-180eea9f56d9.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_0640_1d41077b-3c5f-4821-8703-b30ee3a02c73.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613934/010_8595_d21e0a79-5f63-482e-a1ec-374170759b41.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1820_6dcdc34a-aa9b-482b-9fd6-d5780dedf168.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_1011_34f22cc4-3be0-4d4a-86e8-1efc5184e56f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0367_2f80ebb7-dfa0-4344-980c-3e34be479a9c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613906/DSC_6174_08dc9529-874f-4e27-871f-14b971d7e9f4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613937/DSC_1421_05d85284-2701-4690-a97a-667e18510d02.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291508/DSC_1765_fcbd02be-d806-41a2-b01a-afa40325b59e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_1039_664edea8-a82e-46d5-9b2a-45c63adacc83.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0154_04fa2676-9c50-44a6-8e06-b353f006df87.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613928/DSC_0626_58440018-bbbb-4fc1-8291-c7f295ed624f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_7881_e2f843a0-1338-47be-af4a-585e68099b86.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615011/FLR_1798_364b4759-b4dd-49a8-8004-17f2f7759ac4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613940/DSC_0944_8cd1565f-0d57-439d-956a-84d67914e512.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0549_143acfce-9347-478a-89d4-6c4fecbb7d65.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615162/DSC_3908_1ee3830b-d3cb-4178-8e5e-c6a381375a47.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613910/DSC_5491_7f296a16-8d89-4eeb-b7fd-a63187cce8d4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1304_bb278578-a05e-40e7-9441-04fd9c0f17aa.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613824/DSC_1252_9dfb2864-2237-4149-b671-a8c30afcad43.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613947/DSC_3217_9de9c284-d1e0-4d2a-b96b-0ec76427e764.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613810/DSC_2161_955ffd26-4ae7-4ac0-b488-0b0de2952a48.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613788/DSC_0583_4e8f43af-9d86-4bef-a431-215eb3e9180f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291557/CAP_1618_3b2888a9-c7d4-4499-bc88-dbfceb1bffec.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613941/DSC_4617_500db1b7-c3d6-47c5-98a1-cb08a5708452.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613827/DSC_8561_475c9594-ee8f-46fc-8178-29b5b85a3bf4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_0427_68d6c76b-c09a-4d56-a4f7-34775240222c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613833/DSC_1081_6bd01a7a-c33d-4afd-8e8f-c729dfdbd913.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_0430_1caff59b-8512-4b2e-9de6-f99cc1a7f6f5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613828/020_4248_34b1acf3-14a4-4c0d-8877-a61c9cf903e5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613941/DSC_3855_13c49c75-c4cb-4db2-9809-6293b256276b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2671_a7342825-c232-49b6-aa66-2d1723eae9f2.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0384_d9108788-4c3a-4769-9c14-96e6e4ab9cff.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613931/010_9989_da26774a-8ba5-4b82-8122-fd2eceea162b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613823/DSC_9407_ba5e4df3-04cd-4e4f-9c91-b58ce1c2e7b2.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5789_eb8f3bb4-a823-47ae-bcfc-1e9f24a2d907.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613788/DSC_0726_a9b3724f-b20c-46f4-a430-750477d68dd4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0844_e3fe9e3a-c988-41d3-82eb-76a8c26ad291.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9088/614548/CAP_0246_9a777945-a29a-4ae6-941b-e67c2418c48a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613946/DSC_4911_037c6ee9-0109-43c4-90e7-9f2f58ca4a42.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614079/A0022_AP_30ea00e5-3bf1-42b0-b8be-23b8d3161688.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613910/DSC_5253_ba2282f4-4240-4e81-98d7-8df1ef4869f7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613828/020_3016_39a2fa66-4ebd-46e4-83ba-3badcccd8124.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613827/DSC_8490_ba9dfb45-3da7-436b-a0b8-3a6d4b4aa95a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_2932_706af719-2420-4c45-bd71-acf23ad7b871.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613586/DSC_0811_e58e7b9f-9ec1-4908-a657-42175d729a8f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614043/A0083_AP_62874e35-463d-440b-bcc1-7a50827c14e3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613900/DSC_4674_4d3e9b71-0940-4ebc-8032-c76f134817c2.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_4168_723fa569-a9cb-4c40-8ac6-56b53daa2daf.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613901/DSC_7093_c479dcb3-ef62-45cd-b6ee-60b322e08036.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0164_c9ce3d4d-0f8a-4304-a4fb-ca1736106d69.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613741/DSC_3964_321e2053-4eb6-4b66-a277-e7940ab7c5be.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613904/CAP_2136_05d30e33-d225-48a9-8d76-144be5c28635.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613903/DSC_0324_c50761f6-fdc9-43f4-baea-d73b80f20ebf.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613884/DSC_8062_30b31919-a16d-46e3-8bc5-eca799ada3ad.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291576/DSC_0334_3092cf75-a306-4c8e-9ef3-96f6e50673cc.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613884/DSC_8411_00e6d9bc-9d60-4020-aef3-6aa168b941a1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0566_25a6ae09-4f6f-49f6-90da-4186ece81748.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613937/DSC_0026_9ce7a936-5597-47f9-b5d3-360e536721f2.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613823/DSC_9485_854ca859-942c-4e5d-9f53-88d1ffac06fc.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20186/CAP_2102_7beab9ca-c28c-4ae9-ac75-24907d3d98eb.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291584/DSC_0092_8a946f0b-e892-46aa-8fb2-1021f21645a5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_1199_6c90a74f-5f32-4fac-b20e-95ce8858fc24.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613947/DSC_3523_17e39e20-93c9-4623-b991-46f5c990cbae.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613828/020_4467_2b9a426f-23cb-4ee8-be6d-d72d0ef7551a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613934/010_9526_4d8ccf8d-bc6c-4fe1-884b-ae54a12e6c69.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615028/DSC_7314_0c610a2f-b04d-43b6-a18b-8d66269af120.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614106/A0036_AP_cd2dd508-cc6c-4ee7-9563-c53dccf51c7d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613939/DSC_0653_40c509ea-7343-41d4-a096-83179a9fb77a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291582/DSC_2372_943cb7b0-2ed8-487a-8997-a6bdf051d14e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613793/DSC_0596_28a288ea-748d-40cd-9157-ee32150d5288.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0266_1a8bcbdf-6d80-4d54-91f3-d2777c49db02.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291673/DSC_4712_14f6e46e-85e4-486d-b008-31a268b94728.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614080/A0001_AP_6bc19cc5-0105-47f1-b13e-d478e40eda63.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613828/020_4457_1dd6a75c-6a2d-4f35-9ac8-0a1223ca633b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613947/DSC_4633_16fd0d9f-039e-47a9-8d9a-dbf8930760f8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3033/231165/010_2821_75606709-7151-4017-b9c4-b5a8906a274b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613824/DSC_0712_6f823952-b35c-45ac-a55e-8cf32d857442.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20246/DSC_0071_82c88c01-b005-4654-b569-7f02afff74ae.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613741/DSC_4820_e32725a1-52f3-42f4-9252-a2ab02ba8253.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613927/DSC_1201_21e24337-a3b9-4955-a905-fc497c46b99e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291554/DSC_0888_94a29bf7-ab81-4897-b7aa-346847848623.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613928/DSC_1468_797a2563-2ed2-46cc-95ef-2009d8357ffa.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613819/_CAP3220_461aab3a-6671-456b-8b89-d664b1b1a696.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613904/CAP_2866_f876557f-de7e-48ed-a9a3-8e06cdc738b8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613748/DSC_1962_26a66d49-87f7-413c-88d7-fb93d476212b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613884/DSC_8632_35323041-c6bb-4009-822c-c42c4c29982d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613926/DSC_3558.JPG',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291551/DSC_4356_36e4f461-a86d-44fc-85f6-07bb17106865.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291518/DSC_0199_5421f0ee-1541-438a-9a13-d6c21417c2f0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615047/DSC_0002_84a626af-7723-4e8b-87e0-e42c353297c5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_0196_e2cab183-1d07-4f86-acaa-173e0e168d34.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613829/DSC_8256_1b18c446-15ef-46e1-93dd-537984f6ec94.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/616171/DSC_0752_e06a627d-7e62-4dd3-98f9-f93426a0f88d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/613742/DSC_6078_0a180ff1-0660-432b-896d-de45fd66f439.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291552/DSC_1946_19fb1b4c-84ea-431d-8f41-d7763583c4d0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_0730_35bbd2fe-fe58-4a63-902d-bd021ec35528.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613899/DSC_4355_4900cf95-932f-45e8-9b06-06ea7e720d10.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613556/DSC_0096_2404b4a8-8ece-4602-b36d-92adc8d477f9.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614905/CAP_0587_3df3150e-e3e8-4781-8a08-1af92f3f65ad.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/583534/DSC_5763_0617cbcf-8da4-4ba9-aba0-b2f48b616867.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613783/ABW_0513_6d6e1a14-a94a-4b39-bee7-cc5ca560d4b7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_0326_8e51e471-c530-4ded-867a-48fad672d9b3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613743/DSC_0119_f8fd40dd-9710-4bf9-84b3-7bfbcc9a2916.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613940/DSC_2007_e173b27e-5731-4de1-bc0d-fbc61122e741.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613794/DSC_3442_cc10c845-083e-417c-998f-1763ffb4acce.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613944/020_9203_5a1e1908-1837-4792-b745-e834120fbf9e.jpg',
# ...
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613939/DSC_0773_db117574-8c8e-4ea1-8922-5ed0a6beea56.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613727/DSC_0756_4e7c6d63-d66d-419c-a5b8-d3e2c23e8115.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613734/ALW_4584_b79b41d0-7ec7-492a-a256-5c77bbfaf82b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613899/DSC_4115_f7e9077d-a758-498b-82e0-953439de2150.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241288/DSC_1582_a37d93da-6ae3-420d-84c3-055e91ffd1bf.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5141_b724801b-28cc-4975-a2ed-4ff5f65d7e25.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613927/DSC_0449_1cd690b3-ba0f-4510-9dd2-f407e96a8bf2.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0365_d4a5470a-cb0a-43a8-b26f-24642d5a4d6c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_0794_35946dfc-7bab-4244-b611-55edc6a99c36.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613811/DSC_0759_119e980d-4bb0-49fd-a479-3d784acc8a1e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613755/DSC_2611_e40ef732-8c69-4b14-a53b-73240efc644f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613904/CAP_2625_2595903a-2fa5-4306-ace0-839199a79ac9.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1504_01963967-035b-4503-b86f-ff99d3bb9c3f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613941/DSC_3976_30bc5c81-f4d5-4b1b-aca9-fbbe0de9a1a7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615077/DSC_4048_4c6778a1-8a6a-41fb-845a-9eb6d79cde83.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613934/010_8375_5b2c099a-61bf-4666-9aac-773a8298f91b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613829/DSC_8094_be1d3099-7205-47f1-bec9-c58d42add286.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613809/DSC_9223_26497b81-adb8-4dcc-ac54-c1d3b382b0c9.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291504/DSC_0453_9fe71d70-4fbe-4862-8352-184bba0497e1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291584/DSC_0330_29df76db-5f4c-4d92-9ec3-d26ec1d44e8b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613946/DSC_5987_0819bd7a-233e-46b8-be0f-0c68ad8f4b0c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613732/DSC_0941_97b6355b-02f8-4d8c-9b7b-3863f5f8aadc.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615185/DSC_4265_b321b6ce-4176-404e-83fc-c08b63277d19.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291506/DSC_0290_6302a666-f0b9-4d36-878f-d357990731e4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613946/DSC_4235_034a4bb3-ff1c-4e1e-b224-e0d741c29d5e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9088/614510/CAP_5080_c5024295-6343-4732-8d97-64c591ffbe0d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20199/DSC_0026_d2b24592-0ecd-4a4e-9d43-9c5eedd67476.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613926/DSC_2533.JPG',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614071/A0013_AP_6d519643-8728-499f-ba14-d967031f1890.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613542/DSC_0910_2ff0867b-95ac-47e0-822b-5571514315ef.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5124_a849a079-5b53-4c44-a63f-9035649cf5d3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20261/DSC_0013_b070a49c-67dd-4fd2-8a0e-6119f48dd1fa.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291573/DSC_0265_da98133a-ba01-4a1e-a497-aadf91471c8a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_0068_b59b0bec-17b7-455d-967f-4b0dba8b1820.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0536_b99a5744-7d2e-444e-806c-fe6261f5fb8c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3439_bae239d9-0095-40e1-9736-d720373fad2e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613926/DSC_2469.JPG',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613926/DSC_3546.JPG',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613827/DSC_9027_52f68a22-5c40-49cd-a075-469fb49ddf08.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291652/DSC_0150_a367d299-ca9c-4cbd-a83c-f022572e004b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613887/DSC_3095_42097d4f-dc12-4309-a43d-2098732d663f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613722/DSC_0432_1a90111c-eb3e-4a92-87c4-5e102d820442.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_2808_10bde41f-9a46-4bf3-8465-d6a2c2dcfb95.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613827/DSC_9290_9ddcea2d-9fe2-4587-98f0-f17f5656e9ec.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241279/DSC_1734_86319bfb-98fd-4cc7-83ea-63e938354d3f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613771/DSC_3520_20026164-ede1-4213-a35c-4d9930573f7d.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291487/Jax-Dela_19ec0a0d-c15e-4f2b-b274-9f9b0163b429.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291582/DSC_2620_09e9db38-0918-492c-a362-c5df3a534f87.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20212/DSC_0314_bd98bd9f-4f1d-4de5-bade-a4a87f5c5618.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0842_e1ef696e-08be-486e-a3ab-3d8d920f9669.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291543/DSC_2784_d8f779bc-f903-4127-81d4-4ffac22f0833.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613911/DSC_2694_e8e4b9cd-fea2-4e68-ad3a-c7878d932708.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0260_5d93023a-eba8-4f9e-8d71-31e362c571f2.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291518/DSC_1235_92b299b5-f474-49fc-8dde-e860408809a5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291584/DSC_0313_3982a2ed-caec-46f6-9ed0-ed4a369236e3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20211/DSC_1039_78207fa1-0198-4f69-b663-b902446ff088.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291506/DSC_0451_a6357a20-b1e8-47be-9368-25932e5ff566.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613944/020_8973_3142930d-e7ab-46e6-a37a-5b90e88803f7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613947/DSC_4610_243f1b01-23a2-46b0-9056-d7af94edb8e5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291547/DSC_2693_f907a831-991b-41ba-8aea-e2b707c8c38c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613586/DSC_0824_4445118c-5bf6-46f5-a956-1bf512cdcb28.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613895/DSC_4432_e8312448-8144-4606-898b-3256856fbceb.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613899/DSC_4554_15256156-82cc-4c0c-8107-9b16acff8dc6.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_2181_a32c065a-c648-425a-99a3-8d4606c68227.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291483/DSC_1882_a2a30066-cbe3-4cbf-9b8c-2ad60d2a9c0f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1781_cea9e165-6015-4d59-98e2-fa920db1b4d4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3014_a1b91ccd-e4e3-49e9-ad0f-1c7b964f3fda.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613895/DSC_5413_f114e092-c47d-4d88-9209-23f884ebba91.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613793/DSC_0484_b607c5a8-0ff2-4583-94b5-67c86becf9cf.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613752/DSC_6589_d518176c-dbf5-4975-83ea-b38eb3531e90.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616222/FEMA_REG_c7f9cb5d-7d34-410c-b344-ecec249b5a81.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613947/DSC_4461_8bf2e41c-11bc-49c8-ab56-ebce68e0a369.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291506/DSC_0115_55adbbbb-ba7d-4f2c-9b44-4882d65d7521.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_2236_ccb4f069-f892-4a57-b7d0-8c99e4f18963.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613829/DSC_0438_4e1bfe47-71cf-482e-8674-8c574d1e2c1b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0785_2a02524b-6f18-4d08-a790-db1a8b7458d8.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0229_bcd1b1a4-803c-4812-ab6b-663c1dfe99cc.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291582/DSC_3016_42a7570b-470a-457a-8803-ad27051f9d17.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613926/DSC_3009.JPG',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2583_2fda563f-1a78-4f4e-8d7a-aaf4f7805b3a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0378_dd31ed92-2691-4ffe-80ad-314769ad3408.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/443391/DSC_4907_1be6e230-05a8-481d-9efc-712fe11dae96.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20212/DSC_0519_e402c49c-abd5-439a-9959-442d95b259c0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613898/DSC_5089_049bfd60-8c19-4789-845d-6e6905f13eb3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613744/DSC_0686_172654e4-e3b1-4136-95ed-01edfa9ccff0.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613937/DSC_1113_806007ce-8927-4127-90bd-ae56cc437e12.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613899/DSC_4132_6d778d4c-546a-410e-9db9-25e7cdf635c4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/100537/Tchefunc_16cb07df-d7d6-4320-867c-bb1c5dfece8a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613542/DSC_0640_68ee66d6-22c4-4cc5-8787-589219ce77d5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613947/DSC_4229_2bc238db-df7b-44e5-9746-fb25d5896928.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613827/DSC_9215_73baff08-eddb-4402-a085-cafa44a62a12.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9086/614947/DSC_2806_807f9ed0-dcb0-40de-ad9b-76f5ff189878.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291508/DSC_1500_c36c9cb5-de90-4c73-9a17-defda6b18d63.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615012/DSC_6968_f16beab6-89e1-48da-a225-336f0acd50d1.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613897/DSC_4372_a64a635c-edfd-4066-9750-fa10397f5c4b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0499_0ec05bdc-fbdb-41fc-9be3-4f270aeb72bf.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3033/231175/CAPIberv_6ef767af-f9c9-45ad-a313-c9cbaf16ade3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9113/615622/DSC_0498_77181544-9837-4aed-8cc0-232c5b1e8fee.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613577/DSC_1081_b8662945-1886-4e1c-ad10-00339f87d491.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613727/DSC_0285_7ccb3589-6472-45eb-991a-eca0733e0a8f.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291633/DSC_3600_61c88e11-0446-49e5-9467-2f0e7f832665.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0599_eea4c7c8-fb13-4d27-9be9-b780bf705837.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613927/DSC_0756_802d10e0-3bff-4ac4-8446-2200aa3e6300.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1344_a6a58515-e35c-4090-a979-925a2388a042.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0924_f456c295-fc78-4f9d-bd22-0ebb8303f042.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615047/DSC_0020_d42f9318-867f-467c-9916-ab775a140d7b.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614143/A0024_AP_4be601ac-8836-4da1-a1d6-c7b9ab7bdf88.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0560_4a2b537a-a175-4780-a0c6-93474cd83d29.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613549/DSC_1201_8ec364a1-0fec-452d-b84d-b7b4b6203ea5.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613870/SORTIE40_fe26bcb1-b72c-454f-bafe-4ac2aae409a6.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613542/DSC_0728_dcb236b9-4217-4c20-8fbe-ebece7bea9b7.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_0866_2e68776b-9e68-4b60-9f6c-2a30bfaecfb3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5119_c9996eff-b9de-41bd-b1cc-6182c3096007.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613827/DSC_8945_170d7954-742c-4d04-9783-57d64183143e.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613827/DSC_8714_0d96f5de-687d-43d4-968f-d41d89a1e21a.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0434_c68d90b6-e68c-405d-92bd-ac99e2e4cffa.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613926/DSC_2848.JPG',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613543/DSC_0364_e8b84a74-cfb6-4c97-976b-bc9c316c64ee.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613752/DSC_6303_7d1391cc-80fb-4739-9686-c0d82eb87c16.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_1116_e2b0b003-92b0-4207-8257-e64e7f5d5913.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613901/DSC_7145_1018019d-6c36-4e6a-afbd-fc6591d6c550.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9075/614054/A0133_AP_06813627-4d0c-4cd3-858b-b0c3cce269ed.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613942/DSC_1726_eec99052-c29f-4a06-94c9-9ad023594448.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291504/CAP_0037_549dbd17-2453-4140-9053-ce1e806759ad.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615038/DSC_0157_ae00717a-ba4f-44bb-8b95-ed40a26f2dc3.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_0536_01ea3379-ee75-4c63-b588-9498c1ae8323.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613884/DSC_8490_8c628fff-8301-4b8b-a82e-87f1c1ebf56c.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613946/DSC_4390_4f016950-e56a-489e-9ed1-c3762293f846.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613549/DSC_1224_ac357362-de0c-4d81-84d1-46076d8ad408.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_0175_28be4666-dedd-4330-8a99-b2179ea375b4.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613884/DSC_8289_5c49f50e-f7f9-4a1a-8dd8-a0b0ff6d2089.jpg',
#  'https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9074/613734/ALW_4556_d34c2316-f713-4496-9f58-1d85fbc64eda.jpg',
#  ...]

# %% [markdown]
# Now that we have the images we're interested in, we're going to generate the true/false labels

# %%
# Load ladi_images_metadata.csv
metadata = pd.read_csv('http://ladi.s3-us-west-2.amazonaws.com/Labels/ladi_images_metadata.csv')

# Generate flood and non-flood metadata
flood_metadata = metadata[metadata['url'].isin(im_flood_lst)]
not_flood_metadata = metadata[metadata['url'].isin(im_not_flood_lst)]

# Generate url and s3_path features into list
flood_meta_lst = flood_metadata['url'].tolist()
flood_meta_s3_lst = flood_metadata['s3_path'].tolist()

not_flood_meta_lst = not_flood_metadata['url'].tolist()
not_flood_meta_s3_lst = not_flood_metadata['s3_path'].tolist()

# Check how many images do not have metadata but have human labels
human_label_only = list(set(im_flood_lst) - set(flood_meta_lst))
print(len(human_label_only))
human_label_non_flood = list(set(im_not_flood_lst) - set(not_flood_meta_lst))
print(len(human_label_non_flood))
# Out:
# 0
# 0

# %% [markdown]
# For the purposes of this exercise, we're going to take just a sample of the overall imagery. We're going to take 100 images that are labeled as flood and 100 that are not:

# %%
from random import sample
# sampling
flood_tiny_lst = sample(flood_meta_s3_lst, 100)
not_flood_tiny_lst = sample(not_flood_meta_s3_lst, 100)
flood_tiny_metadata = metadata[metadata['s3_path'].isin(flood_tiny_lst+not_flood_tiny_lst)]

# creating the new datasets
flood_data = []
for path in flood_tiny_lst:
    data_lst = []
    data_lst.append(path)
    data_lst.append(True)
    flood_data.append(data_lst)

not_flood_data = []
for path in not_flood_tiny_lst:
    data_lst = []
    data_lst.append(path)
    data_lst.append(False)
    not_flood_data.append(data_lst)

label_data = flood_data+not_flood_data
label_df = pd.DataFrame(label_data, columns = ['s3_path', 'label']) 

flood_tiny_metadata.to_csv('flood_tiny_metadata.csv')
label_df.to_csv('flood_tiny_label.csv')

# %% [markdown]
# ### Exercise
# Take a look at the LADI csv files. Find some classification task that you find meaningful (e.g. detecting a bridge in an image). Create a csv file like the ones above for the metadata and the label. You might have to do some additional steps in data cleaning, depending on your choice
